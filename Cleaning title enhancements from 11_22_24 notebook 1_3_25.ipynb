# %%
import requests
import json
import polars as pl
import pandas as pd
import numpy as np
import time
import snowflake.connector
from snowflake.connector.pandas_tools import write_pandas
from datetime import datetime

# %% [markdown]
# ## read in production info

# %%
iteminfo = pl.read_json("lw_item_info_11_22_24.json") # data from mongo
iteminfo = iteminfo.to_pandas()
iteminfo = iteminfo.drop(['_id'], axis=1).copy()
iteminfo.columns = [i.upper() for i in iteminfo.columns]
iteminfo.head()
# Out:
#                                             KEYWORDS  \
# 0                                 [police, gangster]
# 1  [videotape, murder, psychopathic-killer, psych...
# 2  [biological weapon, philadelphia, pennsylvania...
# 3  [biological weapon, philadelphia, pennsylvania...
# 4                    [mixed-marriage, gambling-debt]
#
#                                                CASTS          DIRECTORS  \
# 0  [Buster Keaton, Jimmy Durante, Roscoe Ates, Ph...  [Edward Sedgwick]
# 1                                                 []                 []
# 2  [Bruce Willis, Madeleine Stowe, Brad Pitt, Chr...    [Terry Gilliam]
# 3  [Bruce Willis, Madeleine Stowe, Brad Pitt, Chr...    [Terry Gilliam]
# 4                                                 []                 []
#
#                     TITLE  TOTALRECOMMENDATIONS  TOTALDISLIKES  TOTALRATINGS  \
# 0             The Gallows                     1              0           1.0
# 1  The Poughkeepsie Tapes                     1              0           1.0
# 2  The Poughkeepsie Tapes                     1              0           1.0
# 3  The Poughkeepsie Tapes                    11              0           2.0
# 4               Firebrand                     0              0           0.0
#
#    AVERAGERATING  AVERAGERATINGFORCALCS                      THIRDPARTYID  \
# 0            NaN                    NaN  0053576ec9fc4137948af2b9d246e27c
# 1            NaN                    NaN  0611f4bec47945239556c5e39ad1a703
# 2            NaN                    NaN  063a6a15e504448bab952735416df380
# 3            3.0                    3.0  063a6a15e504448bab952735416df380
# 4            NaN                    NaN  0971712630f04584a0d9aa510bb0d27f
#
#   THIRDPARTYPROVIDER      IMDBID CATEGORY  \
# 0             CUSTOM   tt0024762   Movies
# 1             CUSTOM   tt1010271   Movies
# 2             CUSTOM   tt0114746   Movies
# 3               TMDB   tt0114746   Movies
# 4             CUSTOM  tt15000156   Movies
#
#                                  PRODUCTIONCOMPANIES
# 0                              [Metro-Goldwyn-Mayer]
# 1                                                 []
# 2  [Universal Pictures, Atlas Entertainment, Clas...
# 3  [Universal Pictures, Atlas Entertainment, Clas...
# 4                                                 []

# %%
iteminfo.columns
# Out:
# Index(['KEYWORDS', 'CASTS', 'DIRECTORS', 'TITLE', 'TOTALRECOMMENDATIONS',
#        'TOTALDISLIKES', 'TOTALRATINGS', 'AVERAGERATING',
#        'AVERAGERATINGFORCALCS', 'THIRDPARTYID', 'THIRDPARTYPROVIDER', 'IMDBID',
#        'CATEGORY', 'PRODUCTIONCOMPANIES'],
#       dtype='object')

# %%
col_names = {
    'KEYWORDS': 'KEYWORDS_BI',
    'CASTS': 'CASTS_BI',
    'DIRECTORS': 'DIRECTORS_BI',
    'TITLE': 'TITLE_BI',
    'TOTALRECOMMENDATIONS': 'TOTAL_RECOMMENDATIONS_BI',
    'TOTALDISLIKES': 'TOTAL_DISLIKES_BI',
    'TOTALRATINGS': 'TOTAL_RATINGS_BI',
    'AVERAGERATING': 'AVERAGE_RATING_BI',
    'AVERAGERATINGFORCALCS': 'AVERAGE_RATING_FOR_CALCS_BI',
    'CATEGORY': 'CATEGORY_BI',
    'THIRDPARTYID': 'THIRD_PARTY_ID_BI',
    'THIRDPARTYPROVIDER': 'THIRD_PARTY_PROVIDER_BI',
    'ITEM_ID_CATEGORY': 'ITEM_ID_CATEGORY_BI',
    'IMDBID': 'IMDB_ID_BI',
    'PRODUCTIONCOMPANIES': 'PRODUCTION_COMPANIES_BI',
    'THIRD_PARTY_ID_BI': 'ITEM_ID_BI'
}

iteminfo = iteminfo.rename(columns=col_names)

# %%
formatted_date = datetime.today().strftime("%Y-%m-%d")
iteminfo['DATE_RETRIEVED_DATE_BI'] = formatted_date

# %%
iteminfo = iteminfo.rename(columns = {'THIRD_PARTY_ID_BI': 'ITEM_ID_BI'})
iteminfo['ITEM_ID_CATEGORY_BI'] = [i[0] + '_' + i[1].lower() for i in zip(iteminfo.ITEM_ID_BI, iteminfo.CATEGORY_BI)]

# %%
col_order = ['ITEM_ID_BI', 
             'ITEM_ID_CATEGORY_BI',
             'THIRD_PARTY_PROVIDER_BI',
             'IMDB_ID_BI', 
             'TITLE_BI', 
             'CATEGORY_BI', 
             'CASTS_BI', 
             'DIRECTORS_BI',
            'PRODUCTION_COMPANIES_BI', 
             'KEYWORDS_BI',
            'TOTAL_RECOMMENDATIONS_BI',
            'TOTAL_DISLIKES_BI',
            'TOTAL_RATINGS_BI',
            'AVERAGE_RATING_BI',
            'AVERAGE_RATING_FOR_CALCS_BI',
            'DATE_RETRIEVED_DATE_BI']

iteminfo = iteminfo[col_order]

# %%
iteminfo[iteminfo.duplicated(subset=['ITEM_ID_CATEGORY_BI'], keep=False)]
# ok theres dupes here.
# Out:
#                               ITEM_ID_BI  \
# 2       063a6a15e504448bab952735416df380
# 3       063a6a15e504448bab952735416df380
# 4       0971712630f04584a0d9aa510bb0d27f
# 5       0971712630f04584a0d9aa510bb0d27f
# 23234                              11977
# ...                                  ...
# 325464                             99652
# 325676  d0d8e6f4e2d34649ba4522075cbf6fd1
# 325677  d0d8e6f4e2d34649ba4522075cbf6fd1
# 325678  f75ff690d7414e73a9d1d994750455ba
# 325679  f75ff690d7414e73a9d1d994750455ba
#
#                             ITEM_ID_CATEGORY_BI THIRD_PARTY_PROVIDER_BI  \
# 2       063a6a15e504448bab952735416df380_movies                  CUSTOM
# 3       063a6a15e504448bab952735416df380_movies                    TMDB
# 4       0971712630f04584a0d9aa510bb0d27f_movies                  CUSTOM
# 5       0971712630f04584a0d9aa510bb0d27f_movies                    TMDB
# 23234                              11977_movies                    TMDB
# ...                                         ...                     ...
# 325464                              99652_shows                  CUSTOM
# 325676   d0d8e6f4e2d34649ba4522075cbf6fd1_shows                  CUSTOM
# 325677   d0d8e6f4e2d34649ba4522075cbf6fd1_shows                    TMDB
# 325678   f75ff690d7414e73a9d1d994750455ba_shows                  CUSTOM
# 325679   f75ff690d7414e73a9d1d994750455ba_shows                    TMDB
#
#         IMDB_ID_BI                       TITLE_BI CATEGORY_BI  \
# 2        tt0114746         The Poughkeepsie Tapes      Movies
# 3        tt0114746         The Poughkeepsie Tapes      Movies
# 4       tt15000156                      Firebrand      Movies
# 5             None                      Firebrand      Movies
# 23234    tt0080487                     Caddyshack      Movies
# ...            ...                            ...         ...
# 325464   tt9257258         KEVIN CAN F**K HIMSELF       Shows
# 325676  tt12327578  Star Trek: Strange New Worlds       Shows
# 325677        None  Star Trek: Strange New Worlds       Shows
# 325678  tt12809988                    Sweet Tooth       Shows
# 325679        None                    Sweet Tooth       Shows
#
#                                                  CASTS_BI     DIRECTORS_BI  \
# 2       [Bruce Willis, Madeleine Stowe, Brad Pitt, Chr...  [Terry Gilliam]
# 3       [Bruce Willis, Madeleine Stowe, Brad Pitt, Chr...  [Terry Gilliam]
# 4                                                      []               []
# 5                                                      []               []
# 23234   [Chevy Chase, Rodney Dangerfield, Ted Knight, ...   [Harold Ramis]
# ...                                                   ...              ...
# 325464  [Annie Murphy, Eric Petersen, Mary Hollis Inbo...               []
# 325676                                                 []               []
# 325677                                                 []               []
# 325678                                                 []               []
# 325679                                                 []               []
#
#                                   PRODUCTION_COMPANIES_BI  \
# 2       [Universal Pictures, Atlas Entertainment, Clas...
# 3       [Universal Pictures, Atlas Entertainment, Clas...
# 4                                                      []
# 5                                                    None
# 23234             [Orion Pictures, Warner Bros. Pictures]
# ...                                                   ...
# 325464                     [AMC Networks, Le Train Train]
# 325676                                                 []
# 325677                                               None
# 325678                                                 []
# 325679                                                 []
#
#                                               KEYWORDS_BI  \
# 2       [biological weapon, philadelphia, pennsylvania...
# 3       [biological weapon, philadelphia, pennsylvania...
# 4                         [mixed-marriage, gambling-debt]
# 5                                                      []
# 23234   [golf course, golf, romantic rivalry, blonde, ...
# ...                                                   ...
# 325464  [secret, boston massachusetts, political campa...
# 325676  [space, alien, starship, planet, captain, futu...
# 325677                                                 []
# 325678                              [frame-up, chocolate]
# 325679                                                 []
#
#         TOTAL_RECOMMENDATIONS_BI  TOTAL_DISLIKES_BI  TOTAL_RATINGS_BI  \
# 2                              1                  0               1.0
# 3                             11                  0               2.0
# 4                              0                  0               0.0
# 5                              0                  0               0.0
# 23234                      49535                471           48763.0
# ...                          ...                ...               ...
# 325464                       290                  7               0.0
# 325676                         0                  0               0.0
# 325677                         0                  0               0.0
# 325678                         1                  0               1.0
# 325679                         2                  0               2.0
#
#         AVERAGE_RATING_BI  AVERAGE_RATING_FOR_CALCS_BI DATE_RETRIEVED_DATE_BI
# 2                     NaN                          NaN             2025-01-03
# 3                     3.0                     3.000000             2025-01-03
# 4                     NaN                          NaN             2025-01-03
# 5                     NaN                          NaN             2025-01-03
# 23234                 3.9                     3.898671             2025-01-03
# ...                   ...                          ...                    ...
# 325464                NaN                          NaN             2025-01-03
# 325676                NaN                          NaN             2025-01-03
# 325677                NaN                          NaN             2025-01-03
# 325678                NaN                          NaN             2025-01-03
# 325679                5.0                     5.000000             2025-01-03
#
# [188 rows x 16 columns]

# %%
iteminfo[iteminfo['ITEM_ID_CATEGORY_BI'] == '99652_shows']
# duplicates
# Out:
#        ITEM_ID_BI ITEM_ID_CATEGORY_BI THIRD_PARTY_PROVIDER_BI IMDB_ID_BI  \
# 325463      99652         99652_shows                    TMDB       None
# 325464      99652         99652_shows                  CUSTOM  tt9257258
#
#                       TITLE_BI CATEGORY_BI  \
# 325463  Kevin Can F**K Himself       Shows
# 325464  KEVIN CAN F**K HIMSELF       Shows
#
#                                                  CASTS_BI DIRECTORS_BI  \
# 325463                                     [Annie Murphy]           []
# 325464  [Annie Murphy, Eric Petersen, Mary Hollis Inbo...           []
#
#                PRODUCTION_COMPANIES_BI  \
# 325463                  [AMC Networks]
# 325464  [AMC Networks, Le Train Train]
#
#                                               KEYWORDS_BI  \
# 325463  [secret, boston-massachusetts, political-campa...
# 325464  [secret, boston massachusetts, political campa...
#
#         TOTAL_RECOMMENDATIONS_BI  TOTAL_DISLIKES_BI  TOTAL_RATINGS_BI  \
# 325463                      1449                154            1511.0
# 325464                       290                  7               0.0
#
#         AVERAGE_RATING_BI  AVERAGE_RATING_FOR_CALCS_BI DATE_RETRIEVED_DATE_BI
# 325463                3.8                     3.778756             2025-01-03
# 325464                NaN                          NaN             2025-01-03

# %%
iteminfo[iteminfo['ITEM_ID_CATEGORY_BI'] == '11977_movies']
# more duplicates
# Out:
#       ITEM_ID_BI ITEM_ID_CATEGORY_BI THIRD_PARTY_PROVIDER_BI IMDB_ID_BI  \
# 23234      11977        11977_movies                    TMDB  tt0080487
# 23235      11977        11977_movies                  CUSTOM  tt0080487
#
#          TITLE_BI CATEGORY_BI  \
# 23234  Caddyshack      Movies
# 23235  Caddyshack      Movies
#
#                                                 CASTS_BI    DIRECTORS_BI  \
# 23234  [Chevy Chase, Rodney Dangerfield, Ted Knight, ...  [Harold Ramis]
# 23235  [Chevy Chase, Rodney Dangerfield, Ted Knight, ...  [Harold Ramis]
#
#                        PRODUCTION_COMPANIES_BI  \
# 23234  [Orion Pictures, Warner Bros. Pictures]
# 23235  [Orion Pictures, Warner Bros. Pictures]
#
#                                              KEYWORDS_BI  \
# 23234  [golf course, golf, romantic rivalry, blonde, ...
# 23235  [competition, lightning, golf, underwear, spor...
#
#        TOTAL_RECOMMENDATIONS_BI  TOTAL_DISLIKES_BI  TOTAL_RATINGS_BI  \
# 23234                     49535                471           48763.0
# 23235                      1835                 24               0.0
#
#        AVERAGE_RATING_BI  AVERAGE_RATING_FOR_CALCS_BI DATE_RETRIEVED_DATE_BI
# 23234                3.9                     3.898671             2025-01-03
# 23235                NaN                          NaN             2025-01-03

# %%
iteminfo[iteminfo['THIRD_PARTY_PROVIDER_BI'] == 'CUSTOM']

# looks like "CUSTOM" provider is the source of dupes.
# Out:
#                               ITEM_ID_BI  \
# 0       0053576ec9fc4137948af2b9d246e27c
# 1       0611f4bec47945239556c5e39ad1a703
# 2       063a6a15e504448bab952735416df380
# 4       0971712630f04584a0d9aa510bb0d27f
# 23235                              11977
# ...                                  ...
# 324161                             97186
# 324281                             97400
# 325464                             99652
# 325676  d0d8e6f4e2d34649ba4522075cbf6fd1
# 325678  f75ff690d7414e73a9d1d994750455ba
#
#                             ITEM_ID_CATEGORY_BI THIRD_PARTY_PROVIDER_BI  \
# 0       0053576ec9fc4137948af2b9d246e27c_movies                  CUSTOM
# 1       0611f4bec47945239556c5e39ad1a703_movies                  CUSTOM
# 2       063a6a15e504448bab952735416df380_movies                  CUSTOM
# 4       0971712630f04584a0d9aa510bb0d27f_movies                  CUSTOM
# 23235                              11977_movies                  CUSTOM
# ...                                         ...                     ...
# 324161                              97186_shows                  CUSTOM
# 324281                              97400_shows                  CUSTOM
# 325464                              99652_shows                  CUSTOM
# 325676   d0d8e6f4e2d34649ba4522075cbf6fd1_shows                  CUSTOM
# 325678   f75ff690d7414e73a9d1d994750455ba_shows                  CUSTOM
#
#         IMDB_ID_BI                       TITLE_BI CATEGORY_BI  \
# 0        tt0024762                    The Gallows      Movies
# 1        tt1010271         The Poughkeepsie Tapes      Movies
# 2        tt0114746         The Poughkeepsie Tapes      Movies
# 4       tt15000156                      Firebrand      Movies
# 23235    tt0080487                     Caddyshack      Movies
# ...            ...                            ...         ...
# 324161  tt10166602                   Love, Victor       Shows
# 324281  tt10574558                  Midnight Mass       Shows
# 325464   tt9257258         KEVIN CAN F**K HIMSELF       Shows
# 325676  tt12327578  Star Trek: Strange New Worlds       Shows
# 325678  tt12809988                    Sweet Tooth       Shows
#
#                                                  CASTS_BI       DIRECTORS_BI  \
# 0       [Buster Keaton, Jimmy Durante, Roscoe Ates, Ph...  [Edward Sedgwick]
# 1                                                      []                 []
# 2       [Bruce Willis, Madeleine Stowe, Brad Pitt, Chr...    [Terry Gilliam]
# 4                                                      []                 []
# 23235   [Chevy Chase, Rodney Dangerfield, Ted Knight, ...     [Harold Ramis]
# ...                                                   ...                ...
# 324161  [Michael Cimino, Ana Ortiz, James Martinez, Ge...                 []
# 324281  [Zach Gilford, Hamish Linklater, Kate Siegel, ...                 []
# 325464  [Annie Murphy, Eric Petersen, Mary Hollis Inbo...                 []
# 325676                                                 []                 []
# 325678                                                 []                 []
#
#                                   PRODUCTION_COMPANIES_BI  \
# 0                                   [Metro-Goldwyn-Mayer]
# 1                                                      []
# 2       [Universal Pictures, Atlas Entertainment, Clas...
# 4                                                      []
# 23235             [Orion Pictures, Warner Bros. Pictures]
# ...                                                   ...
# 324161                      [20th Century Fox Television]
# 324281                                [Intrepid Pictures]
# 325464                     [AMC Networks, Le Train Train]
# 325676                                                 []
# 325678                                                 []
#
#                                               KEYWORDS_BI  \
# 0                                      [police, gangster]
# 1       [videotape, murder, psychopathic-killer, psych...
# 2       [biological weapon, philadelphia, pennsylvania...
# 4                         [mixed-marriage, gambling-debt]
# 23235   [competition, lightning, golf, underwear, spor...
# ...                                                   ...
# 324161  [gay, friendship, love, 2020s, high school, ne...
# 324281  [island, vampire, community, secret, priest, h...
# 325464  [secret, boston massachusetts, political campa...
# 325676  [space, alien, starship, planet, captain, futu...
# 325678                              [frame-up, chocolate]
#
#         TOTAL_RECOMMENDATIONS_BI  TOTAL_DISLIKES_BI  TOTAL_RATINGS_BI  \
# 0                              1                  0               1.0
# 1                              1                  0               1.0
# 2                              1                  0               1.0
# 4                              0                  0               0.0
# 23235                       1835                 24               0.0
# ...                          ...                ...               ...
# 324161                      7550                 13               0.0
# 324281                       194                  3               0.0
# 325464                       290                  7               0.0
# 325676                         0                  0               0.0
# 325678                         1                  0               1.0
#
#         AVERAGE_RATING_BI  AVERAGE_RATING_FOR_CALCS_BI DATE_RETRIEVED_DATE_BI
# 0                     NaN                          NaN             2025-01-03
# 1                     NaN                          NaN             2025-01-03
# 2                     NaN                          NaN             2025-01-03
# 4                     NaN                          NaN             2025-01-03
# 23235                 NaN                          NaN             2025-01-03
# ...                   ...                          ...                    ...
# 324161                NaN                          NaN             2025-01-03
# 324281                NaN                          NaN             2025-01-03
# 325464                NaN                          NaN             2025-01-03
# 325676                NaN                          NaN             2025-01-03
# 325678                NaN                          NaN             2025-01-03
#
# [115 rows x 16 columns]

# %%
iteminfo = iteminfo[iteminfo['THIRD_PARTY_PROVIDER_BI'] != "CUSTOM"].copy()


# checking for dupes again
iteminfo[iteminfo.duplicated(subset=['ITEM_ID_CATEGORY_BI'], keep=False)]
# there's none. perfect
# Out:
# Empty DataFrame
# Columns: [ITEM_ID_BI, ITEM_ID_CATEGORY_BI, THIRD_PARTY_PROVIDER_BI, IMDB_ID_BI, TITLE_BI, CATEGORY_BI, CASTS_BI, DIRECTORS_BI, PRODUCTION_COMPANIES_BI, KEYWORDS_BI, TOTAL_RECOMMENDATIONS_BI, TOTAL_DISLIKES_BI, TOTAL_RATINGS_BI, AVERAGE_RATING_BI, AVERAGE_RATING_FOR_CALCS_BI, DATE_RETRIEVED_DATE_BI]
# Index: []

# %% [markdown]
# ## fold in the imdb data

# %%
coop = pl.read_json("lw_imdbcooper_titles_11_22_24.json") # imdb data, dumped to json from mongo

# %%
coop = coop.with_columns(
    pl.col("companies").struct.field("distribution").alias("distribution_companies"),
    pl.col("companies").struct.field("production").alias("production_companies")
)

# %%
coop = coop.with_columns(
    pl.col("imdbRating").struct.field("rating").alias("imdb_rating"),
    pl.col("imdbRating").struct.field("numberOfVotes").alias("imdb_number_of_votes")
)

# %%
coop = coop.to_pandas()
coop = coop.drop(['_id', 'companies', 'imdbRating'], axis=1)

coop.head()
# Out:
#      titleId countries                                             genres  \
# 0  tt0000009      [US]                                          [Romance]
# 1  tt0000147      [US]                         [Documentary, News, Sport]
# 2  tt0000502      [ES]                                               None
# 3  tt0000574      [AU]  [Action, Adventure, Biography, Crime, Drama, H...
# 4  tt0000591      [FR]                                            [Drama]
#
#                                             keywords  \
# 0  [character-name-as-title, two-word-title, nick...
# 1  [national-film-registry, first-of-its-kind, pa...
# 2                                [based-on-zarzuela]
# 3  [first-of-its-kind, directorial-debut, austral...
# 4                                               None
#
#                    originalTitle titleType    year distribution_companies  \
# 0                     Miss Jerry     movie  1894.0                   None
# 1  The Corbett-Fitzsimmons Fight     movie  1897.0                   None
# 2                       Bohemios     movie  1905.0                   None
# 3    The Story of the Kelly Gang     movie  1906.0     [The Video Cellar]
# 4               The Prodigal Son     movie  1907.0         [Pathé Frères]
#
#                    production_companies  imdb_rating  imdb_number_of_votes
# 0          [Alexander Black Photoplays]          5.3                 204.0
# 1                   [Veriscope Company]          5.3                 465.0
# 2                    [Gaumont Española]          4.1                  15.0
# 3  [J. and N. Tait, Johnson and Gibson]          6.0                 818.0
# 4                        [Pathé Frères]          4.4                  20.0

# %%
coop.columns = [i.upper() for i in coop.columns]

# %%
rename_cols = {
    'TITLEID': 'IMDB_ID_BI',
    'COUNTRIES': 'COUNTRIES_BI',
    'GENRES': 'GENRES_BI',
    'KEYWORDS': 'KEYWORDS2_BI',
    'ORIGINALTITLE': 'ORIGINAL_TITLE_BI',
    'TITLETYPE': 'TITLE_TYPE_BI',
    'YEAR': 'YEAR_BI',
    'DISTRIBUTION_COMPANIES': 'DISTRIBUTION_COMPANIES_BI',
    'PRODUCTION_COMPANIES': 'PRODUCTION_COMPANIES2_BI',
    'IMDB_RATING': 'IMDB_RATING_BI',
    'IMDB_NUMBER_OF_VOTES': 'IMDB_NUMBER_OF_VOTES_BI'
}

coop = coop.rename(columns=rename_cols)

# %%
merge1 = pd.merge(iteminfo, coop, how='left', left_on='IMDB_ID_BI', right_on='IMDB_ID_BI')
merge1.head()
# The Poughkeepsie Tapes and 12 Monkeys mismatch, row index 0
# Out:
#                          ITEM_ID_BI                      ITEM_ID_CATEGORY_BI  \
# 0  063a6a15e504448bab952735416df380  063a6a15e504448bab952735416df380_movies
# 1  0971712630f04584a0d9aa510bb0d27f  0971712630f04584a0d9aa510bb0d27f_movies
# 2                               100                               100_movies
# 3                             10000                             10000_movies
# 4                           1000003                           1000003_movies
#
#   THIRD_PARTY_PROVIDER_BI  IMDB_ID_BI                             TITLE_BI  \
# 0                    TMDB   tt0114746               The Poughkeepsie Tapes
# 1                    TMDB        None                            Firebrand
# 2                    TMDB   tt0120735  Lock, Stock and Two Smoking Barrels
# 3                    TMDB   tt0109747            The Strategy of the Snail
# 4                    TMDB  tt12298986             Graham Kay: Stupid Jokes
#
#   CATEGORY_BI                                           CASTS_BI  \
# 0      Movies  [Bruce Willis, Madeleine Stowe, Brad Pitt, Chr...
# 1      Movies                                                 []
# 2      Movies  [Jason Flemyng, Dexter Fletcher, Nick Moran, J...
# 3      Movies  [Fausto Cabrera, Frank Ramírez, Delfina Guido,...
# 4      Movies                                       [Graham Kay]
#
#        DIRECTORS_BI                            PRODUCTION_COMPANIES_BI  \
# 0   [Terry Gilliam]  [Universal Pictures, Atlas Entertainment, Clas...
# 1                []                                               None
# 2     [Guy Ritchie]  [Summit Entertainment, The Steve Tisch Company...
# 3  [Sergio Cabrera]  [Ministère de la Culture et de la Francophonie...
# 4    [Mathieu Baer]                       [Just For Laughs Television]
#
#                                          KEYWORDS_BI  ...  COUNTRIES_BI  \
# 0  [biological weapon, philadelphia, pennsylvania...  ...          [US]
# 1                                                 []  ...           NaN
# 2  [gangster, violence, united kingdom, money, ga...  ...          [GB]
# 3  [anarchism, police officer, graffiti, city, gr...  ...  [CO, IT, FR]
# 4                                  [stand-up comedy]  ...           NaN
#
#                      GENRES_BI  \
# 0  [Mystery, Sci-Fi, Thriller]
# 1                          NaN
# 2      [Action, Comedy, Crime]
# 3              [Comedy, Drama]
# 4                          NaN
#
#                                         KEYWORDS2_BI  \
# 0  [male-time-traveler, brunette-woman, white-coa...
# 1                                                NaN
# 2  [low-budget-film, dark-comedy, violence, unite...
# 3  [fissure, police-officer, graffiti, stain-on-a...
# 4                                                NaN
#
#                      ORIGINAL_TITLE_BI  TITLE_TYPE_BI YEAR_BI  \
# 0                           12 Monkeys          movie  1995.0
# 1                                  NaN            NaN     NaN
# 2  Lock, Stock and Two Smoking Barrels          movie  1998.0
# 3            La estrategia del caracol          movie  1993.0
# 4                                  NaN            NaN     NaN
#
#                            DISTRIBUTION_COMPANIES_BI  \
# 0  [Universal Studios, Ascot Elite Entertainment ...
# 1                                                NaN
# 2  [BV-film AS, Becker Entertainment, Columbia Tr...
# 3     [Argentina Video Home, Cinemussy, trigon-film]
# 4                                                NaN
#
#                             PRODUCTION_COMPANIES2_BI IMDB_RATING_BI  \
# 0  [Universal Pictures, Atlas Entertainment, Clas...            8.0
# 1                                                NaN            NaN
# 2  [Summit Entertainment, The Steve Tisch Company...            8.2
# 3  [Caracol Televisión, Compañía de Fomento Cinem...            7.7
# 4                                                NaN            NaN
#
#   IMDB_NUMBER_OF_VOTES_BI
# 0                624917.0
# 1                     NaN
# 2                589412.0
# 3                  2642.0
# 4                     NaN
#
# [5 rows x 26 columns]

# %%
merge1[merge1.duplicated(subset=['ITEM_ID_CATEGORY_BI'], keep=False)]
# no dupes after the merge
# Out:
# Empty DataFrame
# Columns: [ITEM_ID_BI, ITEM_ID_CATEGORY_BI, THIRD_PARTY_PROVIDER_BI, IMDB_ID_BI, TITLE_BI, CATEGORY_BI, CASTS_BI, DIRECTORS_BI, PRODUCTION_COMPANIES_BI, KEYWORDS_BI, TOTAL_RECOMMENDATIONS_BI, TOTAL_DISLIKES_BI, TOTAL_RATINGS_BI, AVERAGE_RATING_BI, AVERAGE_RATING_FOR_CALCS_BI, DATE_RETRIEVED_DATE_BI, COUNTRIES_BI, GENRES_BI, KEYWORDS2_BI, ORIGINAL_TITLE_BI, TITLE_TYPE_BI, YEAR_BI, DISTRIBUTION_COMPANIES_BI, PRODUCTION_COMPANIES2_BI, IMDB_RATING_BI, IMDB_NUMBER_OF_VOTES_BI]
# Index: []
#
# [0 rows x 26 columns]

# %%
# merge1[merge1['TITLE_BI'] == '12 Monkeys']
# how many mismatches are there?
merge1[
    merge1['ORIGINAL_TITLE_BI'].notnull() & 
    (merge1['ORIGINAL_TITLE_BI'] != merge1['TITLE_BI']) & 
    merge1['COUNTRIES_BI'].apply(lambda x: 'US' in x if isinstance(x, np.ndarray) else False)
]

# nearly 30k mismatches for all countries
# 5,400 for US countries
# Out:
#                               ITEM_ID_BI  \
# 0       063a6a15e504448bab952735416df380
# 40                               1000283
# 55                               1000368
# 66                               1000475
# 80                               1000553
# ...                                  ...
# 324932                             98963
# 325234                              9946
# 325273                             99511
# 325425                              9977
# 325497                              9989
#
#                             ITEM_ID_CATEGORY_BI THIRD_PARTY_PROVIDER_BI  \
# 0       063a6a15e504448bab952735416df380_movies                    TMDB
# 40                               1000283_movies                    TMDB
# 55                               1000368_movies                    TMDB
# 66                               1000475_movies                    TMDB
# 80                               1000553_movies                    TMDB
# ...                                         ...                     ...
# 324932                              98963_shows                    TMDB
# 325234                               9946_shows                    TMDB
# 325273                              99511_shows                    TMDB
# 325425                               9977_shows                    TMDB
# 325497                               9989_shows                    TMDB
#
#         IMDB_ID_BI                                  TITLE_BI CATEGORY_BI  \
# 0        tt0114746                    The Poughkeepsie Tapes      Movies
# 40      tt11605552          Tethered, Are We the Experiment?      Movies
# 55       tt4332600  Elmore Leonard: "But Don't Try to Write"      Movies
# 66      tt21291992                                River Wild      Movies
# 80       tt7889878                 We Bought A Haunted House      Movies
# ...            ...                                       ...         ...
# 324932   tt2288831                           Hollywood Girls       Shows
# 325234   tt0078586                               Co-Ed Fever       Shows
# 325273   tt3076808      America the Wild with Casey Anderson       Shows
# 325425   tt0040028            Arthur Godfrey's Talent Scouts       Shows
# 325497   tt0335704          Live from the Metropolitan Opera       Shows
#
#                                                  CASTS_BI  \
# 0       [Bruce Willis, Madeleine Stowe, Brad Pitt, Chr...
# 40      [Dr. Dimitri Christakis MD, MPH, Jessica Wong,...
# 55      [Campbell Scott, Wendy Calhoun, Bridgett M. Da...
# 66      [Adam Brody, Leighton Meester, Taran Killam, O...
# 80                                                     []
# ...                                                   ...
# 324932                                 [Nabilla Benattia]
# 325234  [Heather Thomas, Alexa Kenin, David Keith, Ham...
# 325273                                   [Casey Anderson]
# 325425                                                 []
# 325497                                                 []
#
#                                DIRECTORS_BI  \
# 0                           [Terry Gilliam]
# 40                         [Daniel Gartzke]
# 55                        [John Mulholland]
# 66                              [Ben Ketai]
# 80      [Ray Etheridge, Migdalia Etheridge]
# ...                                     ...
# 324932                                   []
# 325234                                   []
# 325273                                   []
# 325425                                   []
# 325497                                   []
#
#                                   PRODUCTION_COMPANIES_BI  \
# 0       [Universal Pictures, Atlas Entertainment, Clas...
# 40                                                     []
# 55      [Transmultimedia Entertainment, Dutch Films, L...
# 66           [Universal 1440 Entertainment, Hero Squared]
# 80                                    [Golden West Films]
# ...                                                   ...
# 324932   [400 Blows Production, La Grosse Equipe, NRJ 12]
# 325234                                                 []
# 325273                                                 []
# 325425                                                 []
# 325497                                                 []
#
#                                               KEYWORDS_BI  ...  COUNTRIES_BI  \
# 0       [biological weapon, philadelphia, pennsylvania...  ...          [US]
# 40                                                     []  ...          [US]
# 55      [biography, writer, crime fiction writer, docu...  ...          [US]
# 66                                         [friend, love]  ...          [US]
# 80                                                     []  ...          [US]
# ...                                                   ...  ...           ...
# 324932                                                 []  ...      [FR, US]
# 325234                            [college, teenage girl]  ...          [US]
# 325273                                         [mountain]  ...          [US]
# 325425                        [1950s, 1940s, competition]  ...          [US]
# 325497          [stage performance, opera, new york city]  ...          [US]
#
#                           GENRES_BI  \
# 0       [Mystery, Sci-Fi, Thriller]
# 40                    [Documentary]
# 55                    [Documentary]
# 66                       [Thriller]
# 80                        [Mystery]
# ...                             ...
# 324932                      [Drama]
# 325234                     [Comedy]
# 325273                 [Reality-TV]
# 325425      [Comedy, Family, Music]
# 325497                    [Musical]
#
#                                              KEYWORDS2_BI  \
# 0       [male-time-traveler, brunette-woman, white-coa...
# 40                                                   None
# 55                                                   None
# 66                                                   None
# 80                                                   None
# ...                                                   ...
# 324932                                               None
# 325234  [college, teenage-girl, canceled-after-one-epi...
# 325273                            [mountain, non-fiction]
# 325425  [talent, talent-contest, 1950s, 1940s, competi...
# 325497  [stage-performance, opera, new-york-city, live...
#
#                               ORIGINAL_TITLE_BI  TITLE_TYPE_BI YEAR_BI  \
# 0                                    12 Monkeys          movie  1995.0
# 40                                     Tethered          movie  2021.0
# 55      Elmore Leonard - But Don't Try to Write          movie  2021.0
# 66                               The River Wild          movie     NaN
# 80                    We Bought a Haunted House          movie  2018.0
# ...                                         ...            ...     ...
# 324932                        Hollywood Girls 2       tvSeries  2012.0
# 325234                              Co-ed Fever       tvSeries  1979.0
# 325273                         America the Wild       tvSeries  2013.0
# 325425                            Talent Scouts       tvSeries  1948.0
# 325497          The Metropolitan Opera Presents       tvSeries  1977.0
#
#                                 DISTRIBUTION_COMPANIES_BI  \
# 0       [Universal Studios, Ascot Elite Entertainment ...
# 40                       [Conscious Content LLC, Filmhub]
# 55      [American Public Television Worldwide, Transmu...
# 66                                                   None
# 80                                    [Golden West Films]
# ...                                                   ...
# 324932                                            [NRJ12]
# 325234                                              [CBS]
# 325273                      [National Geographic Channel]
# 325425                                      [CBS, Vioobu]
# 325497                [Public Broadcasting Service (PBS)]
#
#                                  PRODUCTION_COMPANIES2_BI IMDB_RATING_BI  \
# 0       [Universal Pictures, Atlas Entertainment, Clas...            8.0
# 40        [Conscious Content LLC, Shaman Motion Pictures]            NaN
# 55                        [Transmultimedia Entertainment]            9.4
# 66           [Universal 1440 Entertainment, Hero Squared]            NaN
# 80                                    [Golden West Films]            2.5
# ...                                                   ...            ...
# 324932    [400 Blows Production, La Grosse Equipe, NRJ12]            4.5
# 325234                                               None            5.1
# 325273                               [Grizzly Peak Films]            8.3
# 325425                                              [CBS]            6.7
# 325497  [Metropolitan Opera Association, The Metropoli...            8.5
#
#        IMDB_NUMBER_OF_VOTES_BI
# 0                     624917.0
# 40                         NaN
# 55                        14.0
# 66                         NaN
# 80                        15.0
# ...                        ...
# 324932                    23.0
# 325234                    45.0
# 325273                    29.0
# 325425                    23.0
# 325497                    45.0
#
# [5423 rows x 26 columns]

# %%
# Dealing with the title mismatch

# I wonder if original title is just the better thing to use to the title mismatch.
# So when original title is there I use original title else title
merge1['TITLE_BI'] = np.where(
    merge1['ORIGINAL_TITLE_BI'].notnull(),  # Condition: ORIGINAL_TITLE_BI is not null
    merge1['ORIGINAL_TITLE_BI'],           # Value if True
    merge1['TITLE_BI']                     # Value if False
)

# %%
merge1.head()
# Out:
#                          ITEM_ID_BI                      ITEM_ID_CATEGORY_BI  \
# 0  063a6a15e504448bab952735416df380  063a6a15e504448bab952735416df380_movies
# 1  0971712630f04584a0d9aa510bb0d27f  0971712630f04584a0d9aa510bb0d27f_movies
# 2                               100                               100_movies
# 3                             10000                             10000_movies
# 4                           1000003                           1000003_movies
#
#   THIRD_PARTY_PROVIDER_BI  IMDB_ID_BI                             TITLE_BI  \
# 0                    TMDB   tt0114746                           12 Monkeys
# 1                    TMDB        None                            Firebrand
# 2                    TMDB   tt0120735  Lock, Stock and Two Smoking Barrels
# 3                    TMDB   tt0109747            La estrategia del caracol
# 4                    TMDB  tt12298986             Graham Kay: Stupid Jokes
#
#   CATEGORY_BI                                           CASTS_BI  \
# 0      Movies  [Bruce Willis, Madeleine Stowe, Brad Pitt, Chr...
# 1      Movies                                                 []
# 2      Movies  [Jason Flemyng, Dexter Fletcher, Nick Moran, J...
# 3      Movies  [Fausto Cabrera, Frank Ramírez, Delfina Guido,...
# 4      Movies                                       [Graham Kay]
#
#        DIRECTORS_BI                            PRODUCTION_COMPANIES_BI  \
# 0   [Terry Gilliam]  [Universal Pictures, Atlas Entertainment, Clas...
# 1                []                                               None
# 2     [Guy Ritchie]  [Summit Entertainment, The Steve Tisch Company...
# 3  [Sergio Cabrera]  [Ministère de la Culture et de la Francophonie...
# 4    [Mathieu Baer]                       [Just For Laughs Television]
#
#                                          KEYWORDS_BI  ...  COUNTRIES_BI  \
# 0  [biological weapon, philadelphia, pennsylvania...  ...          [US]
# 1                                                 []  ...           NaN
# 2  [gangster, violence, united kingdom, money, ga...  ...          [GB]
# 3  [anarchism, police officer, graffiti, city, gr...  ...  [CO, IT, FR]
# 4                                  [stand-up comedy]  ...           NaN
#
#                      GENRES_BI  \
# 0  [Mystery, Sci-Fi, Thriller]
# 1                          NaN
# 2      [Action, Comedy, Crime]
# 3              [Comedy, Drama]
# 4                          NaN
#
#                                         KEYWORDS2_BI  \
# 0  [male-time-traveler, brunette-woman, white-coa...
# 1                                                NaN
# 2  [low-budget-film, dark-comedy, violence, unite...
# 3  [fissure, police-officer, graffiti, stain-on-a...
# 4                                                NaN
#
#                      ORIGINAL_TITLE_BI  TITLE_TYPE_BI YEAR_BI  \
# 0                           12 Monkeys          movie  1995.0
# 1                                  NaN            NaN     NaN
# 2  Lock, Stock and Two Smoking Barrels          movie  1998.0
# 3            La estrategia del caracol          movie  1993.0
# 4                                  NaN            NaN     NaN
#
#                            DISTRIBUTION_COMPANIES_BI  \
# 0  [Universal Studios, Ascot Elite Entertainment ...
# 1                                                NaN
# 2  [BV-film AS, Becker Entertainment, Columbia Tr...
# 3     [Argentina Video Home, Cinemussy, trigon-film]
# 4                                                NaN
#
#                             PRODUCTION_COMPANIES2_BI IMDB_RATING_BI  \
# 0  [Universal Pictures, Atlas Entertainment, Clas...            8.0
# 1                                                NaN            NaN
# 2  [Summit Entertainment, The Steve Tisch Company...            8.2
# 3  [Caracol Televisión, Compañía de Fomento Cinem...            7.7
# 4                                                NaN            NaN
#
#   IMDB_NUMBER_OF_VOTES_BI
# 0                624917.0
# 1                     NaN
# 2                589412.0
# 3                  2642.0
# 4                     NaN
#
# [5 rows x 26 columns]

# %%
def merge_and_unique_lists(tup):
    try:
        list1 = list(tup[0])
        list2 = list(tup[1])
        return list({item.lower() for item in list1 + list2})
    except Exception as e:
        return []

# %%
merge1['PRODUCTION_COMPANIES_BI'] = [[] if isinstance(i, float) else i for i in merge1.PRODUCTION_COMPANIES_BI]
merge1['KEYWORDS_BI'] = [[] if isinstance(i, float) else i for i in merge1.KEYWORDS_BI]
merge1['PRODUCTION_COMPANIES2_BI'] = [[] if isinstance(i, float) else i for i in merge1.PRODUCTION_COMPANIES2_BI]
merge1['KEYWORDS2_BI'] = [[] if isinstance(i, float) else i for i in merge1.KEYWORDS2_BI]

merge1['PRODUCTION_COMPANIES_BI'] = [merge_and_unique_lists(i) for i in zip(merge1.PRODUCTION_COMPANIES_BI, merge1.PRODUCTION_COMPANIES2_BI)]
merge1['KEYWORDS_BI'] = [merge_and_unique_lists(i) for i in zip(merge1.KEYWORDS_BI, merge1.KEYWORDS2_BI)]

# %%
drop_these = ['ORIGINAL_TITLE_BI', 'KEYWORDS2_BI', 'TITLE_TYPE_BI', 'PRODUCTION_COMPANIES2_BI']

merge1 = merge1.drop(drop_these, axis=1)

# %%
column_order = ['ITEM_ID_BI', 
                'ITEM_ID_CATEGORY_BI', 
                'THIRD_PARTY_PROVIDER_BI',
                'IMDB_ID_BI', 
                'TITLE_BI', 
                'CATEGORY_BI', 
                'GENRES_BI', # not in
                'YEAR_BI', # not in
                'COUNTRIES_BI', # not in
                'CASTS_BI', 
                'DIRECTORS_BI',
                'PRODUCTION_COMPANIES_BI', 
                'DISTRIBUTION_COMPANIES_BI',
                'KEYWORDS_BI', 
                'TOTAL_RECOMMENDATIONS_BI',
                'TOTAL_DISLIKES_BI', 
                'TOTAL_RATINGS_BI', 
                'AVERAGE_RATING_BI',
                'AVERAGE_RATING_FOR_CALCS_BI', 
                'DATE_RETRIEVED_DATE_BI',
                'IMDB_RATING_BI',
                'IMDB_NUMBER_OF_VOTES_BI']

merge1 = merge1[column_order].copy()

# %%
merge1.head()
# 12 Monkeys solved.
# Out:
#                          ITEM_ID_BI                      ITEM_ID_CATEGORY_BI  \
# 0  063a6a15e504448bab952735416df380  063a6a15e504448bab952735416df380_movies
# 1  0971712630f04584a0d9aa510bb0d27f  0971712630f04584a0d9aa510bb0d27f_movies
# 2                               100                               100_movies
# 3                             10000                             10000_movies
# 4                           1000003                           1000003_movies
#
#   THIRD_PARTY_PROVIDER_BI  IMDB_ID_BI                             TITLE_BI  \
# 0                    TMDB   tt0114746                           12 Monkeys
# 1                    TMDB        None                            Firebrand
# 2                    TMDB   tt0120735  Lock, Stock and Two Smoking Barrels
# 3                    TMDB   tt0109747            La estrategia del caracol
# 4                    TMDB  tt12298986             Graham Kay: Stupid Jokes
#
#   CATEGORY_BI                    GENRES_BI  YEAR_BI  COUNTRIES_BI  \
# 0      Movies  [Mystery, Sci-Fi, Thriller]   1995.0          [US]
# 1      Movies                          NaN      NaN           NaN
# 2      Movies      [Action, Comedy, Crime]   1998.0          [GB]
# 3      Movies              [Comedy, Drama]   1993.0  [CO, IT, FR]
# 4      Movies                          NaN      NaN           NaN
#
#                                             CASTS_BI  ...  \
# 0  [Bruce Willis, Madeleine Stowe, Brad Pitt, Chr...  ...
# 1                                                 []  ...
# 2  [Jason Flemyng, Dexter Fletcher, Nick Moran, J...  ...
# 3  [Fausto Cabrera, Frank Ramírez, Delfina Guido,...  ...
# 4                                       [Graham Kay]  ...
#
#                            DISTRIBUTION_COMPANIES_BI  \
# 0  [Universal Studios, Ascot Elite Entertainment ...
# 1                                                NaN
# 2  [BV-film AS, Becker Entertainment, Columbia Tr...
# 3     [Argentina Video Home, Cinemussy, trigon-film]
# 4                                                NaN
#
#                                          KEYWORDS_BI TOTAL_RECOMMENDATIONS_BI  \
# 0  [beaten-to-death, microbiologist, airplane, re...                       11
# 1                                                 []                        0
# 2  [beaten-to-death, con-man, snorricam, drink-th...                     2001
# 3  [transgender, gun-shooting, revenge, fissure, ...                        2
# 4                                  [stand-up comedy]                        0
#
#   TOTAL_DISLIKES_BI  TOTAL_RATINGS_BI  AVERAGE_RATING_BI  \
# 0                 0               2.0                3.0
# 1                 0               0.0                NaN
# 2                17            1983.0                3.9
# 3                 0               2.0                NaN
# 4                 0               0.0                NaN
#
#    AVERAGE_RATING_FOR_CALCS_BI  DATE_RETRIEVED_DATE_BI  IMDB_RATING_BI  \
# 0                     3.000000              2025-01-03             8.0
# 1                          NaN              2025-01-03             NaN
# 2                     3.906556              2025-01-03             8.2
# 3                          NaN              2025-01-03             7.7
# 4                          NaN              2025-01-03             NaN
#
#   IMDB_NUMBER_OF_VOTES_BI
# 0                624917.0
# 1                     NaN
# 2                589412.0
# 3                  2642.0
# 4                     NaN
#
# [5 rows x 22 columns]

# %%
merge1[merge1.duplicated(subset=['ITEM_ID_CATEGORY_BI'], keep=False)]
# no dupes after processing merge1. Now on the merging the TMDB data
# Out:
# Empty DataFrame
# Columns: [ITEM_ID_BI, ITEM_ID_CATEGORY_BI, THIRD_PARTY_PROVIDER_BI, IMDB_ID_BI, TITLE_BI, CATEGORY_BI, GENRES_BI, YEAR_BI, COUNTRIES_BI, CASTS_BI, DIRECTORS_BI, PRODUCTION_COMPANIES_BI, DISTRIBUTION_COMPANIES_BI, KEYWORDS_BI, TOTAL_RECOMMENDATIONS_BI, TOTAL_DISLIKES_BI, TOTAL_RATINGS_BI, AVERAGE_RATING_BI, AVERAGE_RATING_FOR_CALCS_BI, DATE_RETRIEVED_DATE_BI, IMDB_RATING_BI, IMDB_NUMBER_OF_VOTES_BI]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ## now on to the tmdb data

# %%
file_path = 'tmdb_show_data_11_21_24.json'
tmdb = pd.read_json(file_path)

# %%
cols_to_keep = ["created_by", 
                   "id", 
                   "name", 
                   "networks",
                 "genres",
                   "origin_country", 
                   "original_name", 
                  "production_companies",
                   "first_air_date",
                   "last_air_date",
                  "type"]

tmdb = tmdb[cols_to_keep].copy()

# %%
def get_value(lst, key_name):
    try:
        return [dikt['name'] for dikt in lst]
    except Exception as e:
        return []

# %%
tmdb['CREATORS'] = [get_value(i, 'name') for i in tmdb.created_by]
tmdb['ORIGINAL_NETWORKS'] = [get_value(i, 'name') for i in tmdb.networks]
tmdb['PRODUCTION_COMPANIES'] = [get_value(i, 'name') for i in tmdb.production_companies]
tmdb['GENRES'] = [get_value(i, 'name') for i in tmdb.genres]

# %%
tmdb = tmdb.drop(['created_by', 'networks', 'production_companies'], axis=1).copy()
tmdb.head()
# Out:
#         id                 name  \
# 0  66732.0      Stranger Things
# 1   2316.0           The Office
# 2   1416.0       Grey's Anatomy
# 3  18165.0  The Vampire Diaries
# 4   1434.0           Family Guy
#
#                                               genres origin_country  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 10765, 'n...           [US]
# 1                     [{'id': 35, 'name': 'Comedy'}]           [US]
# 2                      [{'id': 18, 'name': 'Drama'}]           [US]
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10765, 'n...           [US]
# 4  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...           [US]
#
#          original_name first_air_date last_air_date      type  \
# 0      Stranger Things     2016-07-15    2022-07-01  Scripted
# 1           The Office     2005-03-24    2013-05-16  Scripted
# 2       Grey's Anatomy     2005-03-27    2024-11-14  Scripted
# 3  The Vampire Diaries     2009-09-10    2017-03-10  Scripted
# 4           Family Guy     1999-01-31    2024-04-17  Scripted
#
#                          CREATORS ORIGINAL_NETWORKS  \
# 0      [Ross Duffer, Matt Duffer]         [Netflix]
# 1                  [Greg Daniels]             [NBC]
# 2                 [Shonda Rhimes]             [ABC]
# 3  [Kevin Williamson, Julie Plec]          [The CW]
# 4               [Seth MacFarlane]             [FOX]
#
#                                 PRODUCTION_COMPANIES  \
# 0  [21 Laps Entertainment, Monkey Massacre Produc...
# 1  [Universal Television, Deedle-Dee Productions,...
# 2  [The Mark Gordon Company, shondaland, ABC Stud...
# 3  [Warner Bros. Television, Alloy Entertainment,...
# 4  [20th Century Fox Television, Fuzzy Door Produ...
#
#                                               GENRES
# 0  [Drama, Sci-Fi & Fantasy, Mystery, Action & Ad...
# 1                                           [Comedy]
# 2                                            [Drama]
# 3                          [Drama, Sci-Fi & Fantasy]
# 4                                [Animation, Comedy]

# %%
tmdb = tmdb.drop(['genres'], axis=1).copy()
tmdb = tmdb.dropna(subset=['id'])
tmdb['ITEM_ID'] = [str(int(i)) for i in tmdb.id]
tmdb = tmdb.drop(['id'], axis=1).copy()
tmdb.columns = [i.upper() for i in tmdb.columns]
tmdb = tmdb.drop(['NAME'], axis=1).copy()
tmdb['ITEM_ID_CATEGORY_BI'] = [i + '_shows' for i in tmdb.ITEM_ID]
tmdb.head()
# Out:
#   ORIGIN_COUNTRY        ORIGINAL_NAME FIRST_AIR_DATE LAST_AIR_DATE      TYPE  \
# 0           [US]      Stranger Things     2016-07-15    2022-07-01  Scripted
# 1           [US]           The Office     2005-03-24    2013-05-16  Scripted
# 2           [US]       Grey's Anatomy     2005-03-27    2024-11-14  Scripted
# 3           [US]  The Vampire Diaries     2009-09-10    2017-03-10  Scripted
# 4           [US]           Family Guy     1999-01-31    2024-04-17  Scripted
#
#                          CREATORS ORIGINAL_NETWORKS  \
# 0      [Ross Duffer, Matt Duffer]         [Netflix]
# 1                  [Greg Daniels]             [NBC]
# 2                 [Shonda Rhimes]             [ABC]
# 3  [Kevin Williamson, Julie Plec]          [The CW]
# 4               [Seth MacFarlane]             [FOX]
#
#                                 PRODUCTION_COMPANIES  \
# 0  [21 Laps Entertainment, Monkey Massacre Produc...
# 1  [Universal Television, Deedle-Dee Productions,...
# 2  [The Mark Gordon Company, shondaland, ABC Stud...
# 3  [Warner Bros. Television, Alloy Entertainment,...
# 4  [20th Century Fox Television, Fuzzy Door Produ...
#
#                                               GENRES ITEM_ID  \
# 0  [Drama, Sci-Fi & Fantasy, Mystery, Action & Ad...   66732
# 1                                           [Comedy]    2316
# 2                                            [Drama]    1416
# 3                          [Drama, Sci-Fi & Fantasy]   18165
# 4                                [Animation, Comedy]    1434
#
#   ITEM_ID_CATEGORY_BI
# 0         66732_shows
# 1          2316_shows
# 2          1416_shows
# 3         18165_shows
# 4          1434_shows

# %%
# make lists into tuples in order to drop dupes
tmdb = tmdb.applymap(lambda x: tuple(x) if isinstance(x, list) else x)

tmdb = tmdb.drop_duplicates()

tmdb = tmdb.applymap(lambda x: list(x) if isinstance(x, tuple) else x)

# %%
tmdb[tmdb.duplicated(subset=['ITEM_ID_CATEGORY_BI'], keep=False)] # no dupes in tmdb
# Out:
# Empty DataFrame
# Columns: [ORIGIN_COUNTRY, ORIGINAL_NAME, FIRST_AIR_DATE, LAST_AIR_DATE, TYPE, CREATORS, ORIGINAL_NETWORKS, PRODUCTION_COMPANIES, GENRES, ITEM_ID, ITEM_ID_CATEGORY_BI]
# Index: []

# %% [markdown]
# ## merging

# %%
merge2 = pd.merge(merge1, tmdb, how='left', left_on='ITEM_ID_CATEGORY_BI', right_on='ITEM_ID_CATEGORY_BI')

# %%
merge2[merge2.duplicated(subset=['ITEM_ID_CATEGORY_BI'], keep=False)] # no dupes in merge2
# Out:
# Empty DataFrame
# Columns: [ITEM_ID_BI, ITEM_ID_CATEGORY_BI, THIRD_PARTY_PROVIDER_BI, IMDB_ID_BI, TITLE_BI, CATEGORY_BI, GENRES_BI, YEAR_BI, COUNTRIES_BI, CASTS_BI, DIRECTORS_BI, PRODUCTION_COMPANIES_BI, DISTRIBUTION_COMPANIES_BI, KEYWORDS_BI, TOTAL_RECOMMENDATIONS_BI, TOTAL_DISLIKES_BI, TOTAL_RATINGS_BI, AVERAGE_RATING_BI, AVERAGE_RATING_FOR_CALCS_BI, DATE_RETRIEVED_DATE_BI, IMDB_RATING_BI, IMDB_NUMBER_OF_VOTES_BI, ORIGIN_COUNTRY, ORIGINAL_NAME, FIRST_AIR_DATE, LAST_AIR_DATE, TYPE, CREATORS, ORIGINAL_NETWORKS, PRODUCTION_COMPANIES, GENRES, ITEM_ID]
# Index: []
#
# [0 rows x 32 columns]

# %%
drop_these = ['ORIGINAL_NAME', 'ITEM_ID']
merge2 = merge2.drop(drop_these, axis=1).copy()
merge2 = merge2.rename(columns = {'TYPE': 'SHOW_TYPE'}).copy()

# %%
def merge_and_unique_lists(tup):    
    try:
        list1 = list(tup[0])
        list2 = list(tup[1])
        return list({item.lower() for item in list1 + list2})
    except Exception as e:
        return []
    
def merge_and_unique_lists_upper(tup):
    try:
        list1 = list(tup[0])
        list2 = list(tup[1])
        return list({item.upper() for item in list1 + list2})
    except Exception as e:
        return []

# %%
#cleaning data types
merge2['GENRES_BI'] = [[] if isinstance(i, float) else i for i in merge2.GENRES_BI]
merge2['PRODUCTION_COMPANIES_BI'] = [[] if isinstance(i, float) else i for i in merge2.PRODUCTION_COMPANIES_BI]
merge2['COUNTRIES_BI'] = [[] if isinstance(i, float) else i for i in merge2.COUNTRIES_BI]

merge2['GENRES'] = [[] if isinstance(i, float) else i for i in merge2.GENRES]
merge2['PRODUCTION_COMPANIES'] = [[] if isinstance(i, float) else i for i in merge2.PRODUCTION_COMPANIES]
merge2['ORIGIN_COUNTRY'] = [[] if isinstance(i, float) else i for i in merge2.ORIGIN_COUNTRY]

# %%
merge2['PRODUCTION_COMPANIES_BI'][0]
# Out:
# ['twelve monkeys productions',
#  'atlas entertainment',
#  'universal pictures',
#  'classico']

# %%
merge2['PRODUCTION_COMPANIES_BI'] = [merge_and_unique_lists(i) for i in zip(merge2.PRODUCTION_COMPANIES_BI, merge2.PRODUCTION_COMPANIES)]
merge2['COUNTRIES_BI'] = [merge_and_unique_lists_upper(i) for i in zip(merge2.COUNTRIES_BI, merge2.ORIGIN_COUNTRY)]
merge2['GENRES_BI'] = [merge_and_unique_lists(i) for i in zip(merge2.GENRES_BI, merge2.GENRES)]

# %%
merge2[merge2['TITLE_BI'] == 'Stranger Things']['COUNTRIES_BI'] # ok, empty lists where needed
# Out:
# 4161            []
# 8950            []
# 10957           []
# 29990           []
# 48427     [US, GB]
# 170625          []
# 207350        [US]
# 223154          []
# 223432          []
# 227960          []
# 232864          []
# 241834          []
# 242851          []
# 242981          []
# 243976          []
# 244194          []
# 244626          []
# 248915          []
# 282066          []
# 305770        [US]
# 320439          []
# Name: COUNTRIES_BI, dtype: object

# %%
merge2 = merge2.drop(['ORIGIN_COUNTRY', 'PRODUCTION_COMPANIES', 'GENRES'], axis=1).copy()

# %%
rename_these = {
    'FIRST_AIR_DATE': 'FIRST_AIR_DATE_BI',
    'LAST_AIR_DATE': 'LAST_AIR_DATE_BI',
    'SHOW_TYPE': 'SHOW_TYPE_BI',
    'CREATORS': 'CREATORS_BI',
    'ORIGINAL_NETWORKS': 'ORIGINAL_NETWORKS_BI'
}

merge2 = merge2.rename(columns=rename_these).copy()

# %%
col_order = ['ITEM_ID_BI', 
             'ITEM_ID_CATEGORY_BI', 
             'THIRD_PARTY_PROVIDER_BI',
             'IMDB_ID_BI', 
             'TITLE_BI', 
             'CATEGORY_BI', 
             'GENRES_BI', 
             'YEAR_BI',
             'COUNTRIES_BI',
             'CASTS_BI', 
             'DIRECTORS_BI', 
             'PRODUCTION_COMPANIES_BI',
             'DISTRIBUTION_COMPANIES_BI', 
             'KEYWORDS_BI', 
             'TOTAL_RECOMMENDATIONS_BI',
             'TOTAL_DISLIKES_BI', 
             'TOTAL_RATINGS_BI', 
             'AVERAGE_RATING_BI',
             'AVERAGE_RATING_FOR_CALCS_BI',
             'FIRST_AIR_DATE_BI',
             'LAST_AIR_DATE_BI', 
             'SHOW_TYPE_BI', 
             'CREATORS_BI',
             'ORIGINAL_NETWORKS_BI',
             'IMDB_RATING_BI', 
             'IMDB_NUMBER_OF_VOTES_BI',
             'DATE_RETRIEVED_DATE_BI']

merge2 = merge2[col_order].copy()

# %%
merge2['YEAR_BI'] = merge2['YEAR_BI'].astype(pd.Int64Dtype())

# %%
merge2.head()
# Out:
#                          ITEM_ID_BI                      ITEM_ID_CATEGORY_BI  \
# 0  063a6a15e504448bab952735416df380  063a6a15e504448bab952735416df380_movies
# 1  0971712630f04584a0d9aa510bb0d27f  0971712630f04584a0d9aa510bb0d27f_movies
# 2                               100                               100_movies
# 3                             10000                             10000_movies
# 4                           1000003                           1000003_movies
#
#   THIRD_PARTY_PROVIDER_BI  IMDB_ID_BI                             TITLE_BI  \
# 0                    TMDB   tt0114746                           12 Monkeys
# 1                    TMDB        None                            Firebrand
# 2                    TMDB   tt0120735  Lock, Stock and Two Smoking Barrels
# 3                    TMDB   tt0109747            La estrategia del caracol
# 4                    TMDB  tt12298986             Graham Kay: Stupid Jokes
#
#   CATEGORY_BI                    GENRES_BI  YEAR_BI  COUNTRIES_BI  \
# 0      Movies  [thriller, sci-fi, mystery]     1995          [US]
# 1      Movies                           []     <NA>            []
# 2      Movies      [crime, comedy, action]     1998          [GB]
# 3      Movies              [comedy, drama]     1993  [CO, IT, FR]
# 4      Movies                           []     <NA>            []
#
#                                             CASTS_BI  ... AVERAGE_RATING_BI  \
# 0  [Bruce Willis, Madeleine Stowe, Brad Pitt, Chr...  ...               3.0
# 1                                                 []  ...               NaN
# 2  [Jason Flemyng, Dexter Fletcher, Nick Moran, J...  ...               3.9
# 3  [Fausto Cabrera, Frank Ramírez, Delfina Guido,...  ...               NaN
# 4                                       [Graham Kay]  ...               NaN
#
#   AVERAGE_RATING_FOR_CALCS_BI FIRST_AIR_DATE_BI LAST_AIR_DATE_BI  \
# 0                    3.000000               NaN              NaN
# 1                         NaN               NaN              NaN
# 2                    3.906556               NaN              NaN
# 3                         NaN               NaN              NaN
# 4                         NaN               NaN              NaN
#
#    SHOW_TYPE_BI  CREATORS_BI  ORIGINAL_NETWORKS_BI  IMDB_RATING_BI  \
# 0           NaN          NaN                   NaN             8.0
# 1           NaN          NaN                   NaN             NaN
# 2           NaN          NaN                   NaN             8.2
# 3           NaN          NaN                   NaN             7.7
# 4           NaN          NaN                   NaN             NaN
#
#    IMDB_NUMBER_OF_VOTES_BI DATE_RETRIEVED_DATE_BI
# 0                 624917.0             2025-01-03
# 1                      NaN             2025-01-03
# 2                 589412.0             2025-01-03
# 3                   2642.0             2025-01-03
# 4                      NaN             2025-01-03
#
# [5 rows x 27 columns]

# %%
merge2[merge2.duplicated(subset=['ITEM_ID_CATEGORY_BI'], keep=False)] # no dupes in merge2
# Out:
# Empty DataFrame
# Columns: [ITEM_ID_BI, ITEM_ID_CATEGORY_BI, THIRD_PARTY_PROVIDER_BI, IMDB_ID_BI, TITLE_BI, CATEGORY_BI, GENRES_BI, YEAR_BI, COUNTRIES_BI, CASTS_BI, DIRECTORS_BI, PRODUCTION_COMPANIES_BI, DISTRIBUTION_COMPANIES_BI, KEYWORDS_BI, TOTAL_RECOMMENDATIONS_BI, TOTAL_DISLIKES_BI, TOTAL_RATINGS_BI, AVERAGE_RATING_BI, AVERAGE_RATING_FOR_CALCS_BI, FIRST_AIR_DATE_BI, LAST_AIR_DATE_BI, SHOW_TYPE_BI, CREATORS_BI, ORIGINAL_NETWORKS_BI, IMDB_RATING_BI, IMDB_NUMBER_OF_VOTES_BI, DATE_RETRIEVED_DATE_BI]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# ### push to snowflake

# %% [raw]
# conn = snowflake.connector.connect(
#     user='user',
#     password='pass',
#     account='account_name',
#     warehouse='warehouse_name',
#     database='db_name',
#     schema='schema_name'
# )

# %% [raw]
# success, num_chunks, num_rows, output = write_pandas(
#     conn,
#     merge2,
#     'table_name'  # Target Snowflake table
# )
